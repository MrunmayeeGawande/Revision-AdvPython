# %% [markdown]
# ## Built in classes in python

# %%
# Age is object of class integer
age = 23
print(age)
print(type(age))
# Out:
# 23
# <class 'int'>

# %%
a = 25
print(a)
print(type(a))
# Out:
# 25
# <class 'int'>

# %%
b = [1, 2, 3, 4, 5]
print(type(b))
# Out:
# <class 'list'>

# %%
# method of class list
b.append(12)
print(b)
# Out:
# [1, 2, 3, 4, 5, 12]

# %%
c = (1, 2, 3, 4, 5)
print(type(c))
# Out:
# <class 'tuple'>

# %%
m = True
print(type(m))
# Out:
# <class 'bool'>

# %%
import pandas as pd

df = pd.DataFrame(
    {
        "id": [1, 2, 3],
        "name": ["Aditi", "Raman", "Rahul"],
        "age": [23, 25, 38],
        "height": [5.5, 6.0, 5.2]
    }
)

df
# Out:
#    id   name  age  height
# 0   1  Aditi   23     5.5
# 1   2  Raman   25     6.0
# 2   3  Rahul   38     5.2

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Attributes of Classes

# %%
df.columns
# Out:
# Index(['id', 'name', 'age', 'height'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.values
# Out:
# array([[1, 'Aditi', 23, 5.5],
#        [2, 'Raman', 25, 6.0],
#        [3, 'Rahul', 38, 5.2]], dtype=object)

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.dtypes
# Out:
# id          int64
# name       object
# age         int64
# height    float64
# dtype: object

# %% [markdown]
# ### Methods of class dataframe

# %%
df.sort_values(by = "age", ascending = False)
# Out:
#    id   name  age  height
# 2   3  Rahul   38     5.2
# 1   2  Raman   25     6.0
# 0   1  Aditi   23     5.5

# %%
df.info
# Out:
# <bound method DataFrame.info of    id   name  age  height
# 0   1  Aditi   23     5.5
# 1   2  Raman   25     6.0
# 2   3  Rahul   38     5.2>

# %% [markdown]
# ### Create a class person
# 1. attributes - properties of the class
# 2. methods - perfrom certain operations based on attributes

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person:

    # Constructor function __init__ to define attributes of class
    # self is any object of class person
    def __init__(self, name: str, age: int, gender: str, occupation: str):
        self.name = name
        self.age = age
        self.gender = gender
        self.occupation = occupation

    # this function is the string representaion of the class
    def __str__(self):
        return f"Person(name = {self.name}, age = {self.age}, gender = {self.gender}, occupation = {self.occupation})"

    # Write a method for class person
    def introduce(self):
        print(f"My name is {self.name}")
        print(f"My age is {self.age}")
        print(f"I am {self.gender}")
        print(f"I work as {self.occupation}")

# %%
# p1 is object of class person
p1 = Person(name="Rahul", age=23, gender="male", occupation="Engg.")
print(type(p1))
# Out:
# <class '__main__.Person'>

# %%
p1

# %%
print(p1)
# Out:
# Person(name = Rahul, age = 23, gender = male, occupation = Engg.)

# %%
p1.name
# Out:
# 'Rahul'

# %%
p1.age
# Out:
# 23

# %%
p1.gender
# Out:
# 'male'

# %%
p1.occupation
# Out:
# 'Engg.'

# %%
p1.introduce()
# Out:
# My name is Rahul
# My age is 23
# I am male
# I work as Engg.

# %%
p2 = Person(name = "Aditi", age=20, gender="female", occupation="Sales")
print(type(p2))
# Out:
# <class '__main__.Person'>

# %%
p2.name
# Out:
# 'Aditi'

# %%
p2.age
# Out:
# 20

# %%
p2.gender
# Out:
# 'female'

# %%
p2.occupation
# Out:
# 'Sales'

# %%
p2.introduce()
# Out:
# My name is Aditi
# My age is 20
# I am female
# I work as Sales

# %%
print(p2)
# Out:
# Person(name = Aditi, age = 20, gender = female, occupation = Sales)

# %% [markdown]
# ### Dataclasses

# %%
from dataclasses import dataclass
from typing import Literal

@dataclass
class Person2:
    name: str
    age: int
    gender: Literal["male", "female"]
    occuptation: str

    def intro(self):
        print(f"My name is {self.name}")
        print(f"My age is {self.age}")
        print(f"I am {self.gender}")
        print(f"I work as {self.occuptation}")

# %%
p3 = Person2(name="Raman", age=25, gender="male", occuptation="HR")
print(p3)
# Out:
# Person2(name='Raman', age=25, gender='male', occuptation='HR')

# %%
print(type(p3))
# Out:
# <class '__main__.Person2'>

# %%
p3.name
# Out:
# 'Raman'

# %%
p3.age
# Out:
# 25

# %%
p4 = Person2(name="Priya", age=30, gender="female", occuptation="Engg.")
print(p4)
# Out:
# Person2(name='Priya', age=30, gender='female', occuptation='Engg.')

# %%
p4.age
# Out:
# 30

# %%
p4.gender
# Out:
# 'female'

# %% [markdown]
# ### Bank account

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
@dataclass
class Account:
    ac_no: int
    name: str
    balance: float
    
    def check_balance(self):
        print(f"Account Number : {self.ac_no}, Name : {self.name}, Balance : {self.balance}")

    def deposit(self, amt: float):
        if amt <= 0:
            raise ValueError("The amount deposited cannot be negative or zero")
        self.balance = self.balance + amt

    def withdraw(self, amt: float):
        if amt <= 0:
            raise ValueError("The amount withdrawn cannot be negative or zero")
        if amt > self.balance:
            raise ValueError("Insufficient balance")
        self.balance = self.balance - amt

    def transfer(self, amt: float, other_ac: 'Account'):
        self.withdraw(amt)
        other_ac.deposit(amt)

# %%
ac1 = Account(ac_no=1234, name="Raman", balance=0)
print(ac1)
# Out:
# Account(ac_no=1234, name='Raman', balance=0)

# %%
ac1.check_balance()
# Out:
# Account Number : 1234, Name : Raman, Balance : 0

# %%
ac1.deposit(1000.0)

# %%
ac1.balance
# Out:
# 1000.0

# %%
ac1.check_balance()
# Out:
# Account Number : 1234, Name : Raman, Balance : 1000.0

# %%
ac1.deposit(-500.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 ac1.deposit(-500.0)
#
# Cell In[42], line 12, in Account.deposit(self, amt)
#      10 def deposit(self, amt: float):
#      11     if amt <= 0:
# ---> 12         raise ValueError("The amount deposited cannot be negative or zero")
#      13     self.balance = self.balance + amt
#
# ValueError: The amount deposited cannot be negative or zero

# %%
ac1.check_balance()
# Out:
# Account Number : 1234, Name : Raman, Balance : 1000.0

# %%
ac1.withdraw(1500.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 ac1.withdraw(1500.0)
#
# Cell In[42], line 19, in Account.withdraw(self, amt)
#      17     raise ValueError("The amount withdrawn cannot be negative or zero")
#      18 if amt > self.balance:
# ---> 19     raise ValueError("Insufficient balance")
#      20 self.balance = self.balance - amt
#
# ValueError: Insufficient balance

# %%
ac1.withdraw(700)

# %%
ac1.check_balance()
# Out:
# Account Number : 1234, Name : Raman, Balance : 300.0

# %% [markdown]
# ## Creating other account

# %%
ac2 = Account(ac_no=7890, name="Aditi", balance=600.0)
print(ac2)
# Out:
# Account(ac_no=7890, name='Aditi', balance=600.0)

# %%
ac2.deposit(800.0)

# %%
ac2.check_balance()
# Out:
# Account Number : 7890, Name : Aditi, Balance : 1400.0

# %%
ac2.withdraw(500.0)

# %%
ac2.check_balance()
# Out:
# Account Number : 7890, Name : Aditi, Balance : 900.0

# %%
ac2.transfer(500, ac1)

# %%
ac1.check_balance()
ac2.check_balance()
# Out:
# Account Number : 1234, Name : Raman, Balance : 800.0
# Account Number : 7890, Name : Aditi, Balance : 400.0

# %%
ac1.transfer(350, ac2)

# %%
ac1.check_balance()
ac2.check_balance()
# Out:
# Account Number : 1234, Name : Raman, Balance : 450.0
# Account Number : 7890, Name : Aditi, Balance : 750.0

# %% [markdown]
# ### Assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
class Triangle:

    def __init__(self, a: int | float , b: int | float, c: int | float):
        self.a = a
        self.b = b 
        self.c = c
        # Check that all sides of triangle are non zero and positive
        if (self.a <= 0) or (self.b <= 0) or (self.c <= 0):
            raise ValueError("Sides cannot be negative or zero")
        if not self.is_triangle():
            raise ValueError("Sum of two sides should always be greater than third")
        
    # String representation
    def __str__(self):
        return f"Triangle(a = {self.a}, b = {self.b}, c = {self.c})"

    def is_triangle(self):
        return (
            (self.a + self.b > self.c) and
            (self.b + self.c > self.a) and
            (self.c + self.a > self.b)
        )

    def perimeter(self):
        return self.a + self.b + self.c

    def area(self):
        s = self.perimeter()/2
        a = math.sqrt(s * (s - self.a) * (s - self.b) * (s - self.c))
        return a

# %%
t1 = Triangle(a=3, b=4, c=5)
type(t1)
# Out:
# __main__.Triangle

# %%
t1.is_triangle()
# Out:
# True

# %%
t1.perimeter()
# Out:
# 12

# %%
t1.area()
# Out:
# 6.0

# %%
t2 = Triangle(a=12, b=13, c=14)
type(t2)
# Out:
# __main__.Triangle

# %%
t2.is_triangle()
# Out:
# True

# %%
t2.perimeter()
# Out:
# 39

# %%
t2.area()
# Out:
# 72.30793524918272

# %%
t3 = Triangle(a=1, b=2, c=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 t3 = Triangle(a=1, b=2, c=3)
#
# Cell In[62], line 12, in Triangle.__init__(self, a, b, c)
#      10     raise ValueError("Sides cannot be negative or zero")
#      11 if not self.is_triangle():
# ---> 12     raise ValueError("Sum of two sides should always be greater than third")
#
# ValueError: Sum of two sides should always be greater than third

# %%
t4 = Triangle(a=-1, b=2, c=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 t4 = Triangle(a=-1, b=2, c=3)
#
# Cell In[62], line 10, in Triangle.__init__(self, a, b, c)
#       8 # Check that all sides of triangle are non zero and positive
#       9 if (self.a <= 0) or (self.b <= 0) or (self.c <= 0):
# ---> 10     raise ValueError("Sides cannot be negative or zero")
#      11 if not self.is_triangle():
#      12     raise ValueError("Sum of two sides should always be greater than third")
#
# ValueError: Sides cannot be negative or zero

# %%
t5 = Triangle(a = 12, b=13, c = 30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 t5 = Triangle(a = 12, b=13, c = 30)
#
# Cell In[62], line 12, in Triangle.__init__(self, a, b, c)
#      10     raise ValueError("Sides cannot be negative or zero")
#      11 if not self.is_triangle():
# ---> 12     raise ValueError("Sum of two sides should always be greater than third")
#
# ValueError: Sum of two sides should always be greater than third

# %%
t3 = Triangle(a=3, b=3, c=3)
t3.perimeter()
# Out:
# 9

# %%
t3.area()
# Out:
# 3.897114317029974
